# %% [markdown]
# # AI Political Supremacy (AIPS) Exploration
# Notebook ini digunakan untuk eksplorasi data politik menggunakan AI.

# %%
# Import pustaka dasar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Menampilkan pesan sukses
print('Notebook AIPS berhasil dijalankan!')
